# %%
import numpy as np
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, ConstantKernel, WhiteKernel
from scipy.stats import norm
from scipy.optimize import minimize
import warnings
warnings.filterwarnings("ignore")

# Change seed to generate NEW query suggestions
np.random.seed(777)


# ==============================
# LOAD DATA
# ==============================
X = np.load("initial_inputs.npy")
y = np.load("initial_outputs.npy").reshape(-1)

if X.ndim == 1:
    X = X.reshape(-1, 1)

N, D_total = X.shape

print("Samples:", N)
print("Total dimension available:", D_total)
print("-" * 50)


# ==============================
# BO FUNCTION
# ==============================
def propose_next_query(X, y):

    n, d = X.shape

    mins = X.min(axis=0)
    maxs = X.max(axis=0)
    bounds = list(zip(mins, maxs))

    kernel = (
        ConstantKernel(1.0) *
        RBF(length_scale=np.ones(d)) +
        WhiteKernel(noise_level=1e-6)
    )

    gp = GaussianProcessRegressor(
        kernel=kernel,
        normalize_y=True,
        n_restarts_optimizer=5
    )

    gp.fit(X, y)

    y_best = np.min(y)
    xi = 1e-3

    def EI(x):
        x = np.asarray(x).reshape(1, d)
        mu, sigma = gp.predict(x, return_std=True)

        mu = mu.item()
        sigma = max(sigma.item(), 1e-12)

        imp = y_best - mu - xi
        Z = imp / sigma

        return imp * norm.cdf(Z) + sigma * norm.pdf(Z)

    # Larger candidate pool for stronger search
    candidates = np.random.uniform(mins, maxs, size=(30000, d))
    eis = np.array([EI(c) for c in candidates])
    x0 = candidates[np.argmax(eis)]

    # Local refinement
    def neg_ei(x):
        return -EI(x)

    best = x0
    best_val = EI(x0)

    for _ in range(20):
        x_init = np.random.uniform(mins, maxs)
        res = minimize(neg_ei, x_init, bounds=bounds, method="L-BFGS-B")

        if res.success and -res.fun > best_val:
            best_val = -res.fun
            best = res.x

    return best


# ==============================
# RUN FOR 2D–8D
# ==============================

results = {}

for D in range(2, min(9, D_total + 1)):

    print(f"\nRunning Bayesian Optimisation for {D}D")

    Xd = X[:, :D]
    next_point = propose_next_query(Xd, y)

    results[D] = next_point

    print("Next query point:")
    print(np.round(next_point, 6))

    np.save(f"next_query_point_round13_{D}d.npy", next_point)

print("\nAll dimensions complete.")

print("\n===== NEW ENTRY POINTS =====")
for D, point in results.items():
    print(f"{D}D → {np.round(point,6)}")
# Out:
# Samples: 40
# Total dimension available: 8
# --------------------------------------------------
#
# Running Bayesian Optimisation for 2D
# Next query point:
# [0.985945 0.834241]
#
# Running Bayesian Optimisation for 3D
# Next query point:
# [0.580925 0.43814  0.663748]
#
# Running Bayesian Optimisation for 4D
# Next query point:
# [0.278787 0.94956  0.461153 0.129397]
#
# Running Bayesian Optimisation for 5D
# Next query point:
# [0.985945 0.97398  0.998885 0.89931  0.51657 ]
#
# Running Bayesian Optimisation for 6D
# Next query point:
# [0.335    0.657727 0.874857 0.724786 0.838176 0.069929]
#
# Running Bayesian Optimisation for 7D
# Next query point:
# [0.985945 0.97398  0.998885 0.902986 0.009649 0.022113 0.992914]
#
# Running Bayesian Optimisation for 8D
# Next query point:
# [0.98478  0.826761 0.979102 0.866098 0.759344 0.132079 0.835398 0.542006]
#
# All dimensions complete.
#
# ===== NEW ENTRY POINTS =====
# 2D → [0.985945 0.834241]
# 3D → [0.580925 0.43814  0.663748]
# 4D → [0.278787 0.94956  0.461153 0.129397]
# 5D → [0.985945 0.97398  0.998885 0.89931  0.51657 ]
# 6D → [0.335    0.657727 0.874857 0.724786 0.838176 0.069929]
# 7D → [0.985945 0.97398  0.998885 0.902986 0.009649 0.022113 0.992914]
# 8D → [0.98478  0.826761 0.979102 0.866098 0.759344 0.132079 0.835398 0.542006]
